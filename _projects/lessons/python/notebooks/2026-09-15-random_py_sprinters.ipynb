# %% [raw]
# ---
# layout: post
# categories: [Python, Random-Values]
# lesson_language: Python
# lesson_topic: Random-Values
# lesson_part: interactive
# lesson_type: lesson
# codemirror: true
# microblog: true
# toc: false
# comments: false
# title: 3.15 Random Values
# description: Learn random values in Python using the five-part LxD lesson format.
# permalink: /python/random
# authors: Ruhaan Bansal, Deyar Raissadat, Arya Taghavi Zargar
# ---

# %% [markdown]
# A **random value** is selected from a set or range of possible values. Python is the main language for this lesson. JavaScript and College Board pseudocode are only used to compare the same idea in different forms.
#
# ## 1. LxD Cycle Process
#
# **Empathize:** Random code can be confusing because students may expect every result to appear once before a repeat, forget that `randint` includes both endpoints, or choose a range with the wrong values.
#
# **Define:**
# - **POV:** CSP students need a simple way to connect familiar random events, such as dice rolls, to the code that creates random values.
# - **Learning Goal:** Students will be able to generate, test, and explain random values in Python.
#
# **Ideate:**
# - **HMW Question:** How might we show randomness in a way that students can predict the possible outputs even though they cannot predict the exact next result?
# - **Activity:** Predict ranges, use `random.choice`, fix a wrong range, and build a small dice game.
#
# **Prototype & Test:** Use the Popcorn Hacks below to check whether students can list possible outputs, recognize valid ranges, and use a random result inside a decision.
#
# ---
#
# ## 2. Lesson Plan
#
# **Learning Objective:** By the end of this lesson, you will be able to use Python's `random` module to generate random integers, choose random list items, and use random results in a program.
#
# **Success Criteria:** You can identify every possible output of a random expression, choose the correct range, and explain why repeated results are allowed.
#
# ### Tech Talk 1: Random Integers
#
# Python's built-in `random` module gives us tools for random values.

# %%
# CODE_RUNNER: Run the random integer example

import random

die_roll = random.randint(1, 6)
print("Die roll:", die_roll)

# %% [markdown]
# `random.randint(a, b)` can return any whole number from `a` through `b`, including both endpoints.
#
# For a normal die, the possible results are `1`, `2`, `3`, `4`, `5`, and `6`.
#
# ### Tech Talk 2: Random Choices
#
# Python can choose directly from a list.

# %%
# CODE_RUNNER: Run the random choice example

import random

activities = ["study", "stretch", "walk", "get water"]
pick = random.choice(activities)

print("Random activity:", pick)

# %% [markdown]
# The result must be one item from the list.
#
# The same random-integer idea looks like this in the three forms:
#
# | Form | Random integer from 1 through 6 |
# | --- | --- |
# | Python | `random.randint(1, 6)` |
# | JavaScript | `Math.floor(Math.random() * 6) + 1` |
# | College Board pseudocode | `RANDOM(1, 6)` |
#
# ### Tech Talk 3: Use Random Values in Decisions
#
# A program can generate a random value and then use that result in an `if` statement.

# %%
# CODE_RUNNER: Run the random decision example

import random

flip = random.randint(1, 2)

if flip == 1:
    print("Heads")
else:
    print("Tails")

# %% [markdown]
# Random does **not** mean every possible result appears once before a repeat. Repeats are normal.
#
# ---
#
# ## 3. Popcorn Hacks & Practice Tasks
#
# > **SFI car/backend theme:** The exercises below use automotive SFI specification records and backend testing. The project stores racing-part data such as product names, categories, spec numbers, and effective dates, including flywheel and clutch-assembly specifications.
#
# ### Popcorn Hack 1: Predict the Record ID Range
#
# Imagine a backend QA script randomly selects one mock SFI car-part record ID to test. Before running the code, identify every possible record ID:

# %%
# CODE_RUNNER: Run Popcorn Hack 1

import random

test_record_id = random.randint(3, 7)
print("Testing SFI part record ID:", test_record_id)

# %% [markdown]
# Answer:
# 1. What is the smallest possible result?
# 2. What is the largest possible result?
# 3. List every possible integer.
# 4. Could it return `2`?
# 5. Could it return `7`?
#
# Then run the code several times and compare the results with your predicted range.
#
# ### Popcorn Hack 2: Random SFI Car Part
#
# A backend test script needs to choose one automotive SFI part record to inspect next.

# %%
# CODE_RUNNER: Run Popcorn Hack 2

import random

sfi_car_parts = [
    "Replacement Flywheels and Clutch Assemblies",
    "Multiple Disc Clutch Assemblies",
    "Racing Flywheel Record"
]

selected_part = random.choice(sfi_car_parts)
print("Backend test part:", selected_part)

# %% [markdown]
# Do these five things:
# 1. List every part name that can be printed.
# 2. Add one more SFI automotive or racing part record.
# 3. Run the code at least five times.
# 4. Explain why the same part can appear more than once.
# 5. Replace the list with a different set of backend car-part test records.
#
# ### Popcorn Hack 3: Fix the Backend Test Range
#
# The backend test database has **four** mock SFI part records numbered `1` through `4`, but this random range is wrong.

# %%
# CODE_RUNNER: Run Popcorn Hack 3

import random

part_record_id = random.randint(0, 3)
print("SFI part record ID:", part_record_id)

# %% [markdown]
# List the current possible results, fix the range so it returns `1` through `4`, and write the corrected random expression in JavaScript and College Board pseudocode.
#
# ### Popcorn Hack 4 / Homework: SFI Backend Part API Randomizer
#
# Build a small Python QA program that randomly chooses an SFI automotive part record and decides which backend action to simulate for it.
#
# Your program must:
# 1. use `random.randint(...)` or `random.choice(...)`,
# 2. have at least three possible car/racing part records,
# 3. use the random result in an `if` / `elif` / `else` or another meaningful backend action,
# 4. print a simulated API/database action such as **GET/search**, **POST/create**, or **PUT/update**,
# 5. still work when a random value repeats,
# 6. include 2–3 sentences explaining the possible outputs.
#
# Possible records can include **Replacement Flywheels and Clutch Assemblies**, **Multiple Disc Clutch Assemblies**, or other SFI automotive parts from the project dataset.
#
# ---
#
# ## 4. Grading Plan (1 Point Total)
#
# | Activity | Points | What earns the points |
# | --- | ---: | --- |
# | Popcorn Hack 1 | 0.2 | Correctly identify the smallest, largest, and all possible backend test record IDs. |
# | Popcorn Hack 2 | 0.2 | Use `random.choice()` correctly, modify the SFI car-part list, and explain why repeats are possible. |
# | Popcorn Hack 3 | 0.2 | Fix the four-record backend test range and correctly write the equivalent JavaScript and College Board pseudocode. |
# | Popcorn Hack 4 / Homework | 0.4 | Build a working SFI backend car-part randomizer with at least three possible part records, use the random result meaningfully in a simulated API/database action, handle repeats, and explain the possible outputs. |
# | **Total** | **1.0** | |
#
# ---
#
# ## 5. Lesson Revisions & Feedback Evidence
#
# - The lesson and Tech Talks keep their original general examples.
# - The Popcorn Hacks and homework now focus on SFI automotive parts and backend database/API testing.
# - The examples use car-part records plus backend-style IDs, search/create/update actions, and random QA selection.
# - Every hack runner prints visible output, including Popcorn Hack 1.
# - Python stays the main coding language, while JavaScript and College Board pseudocode are short comparison aids.
# - Feedback from a practice run can be added here with the specific change that was made because of it.
