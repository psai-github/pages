# %% [raw]
# ---
# layout: post
# categories: [Python, Random-Values]
# lesson_language: Python
# lesson_topic: Random-Values
# lesson_part: interactive
# lesson_type: lesson
# codemirror: true
# microblog: true
# assignment: true
# assignment_name: 3.15 Random Values - SFI Backend
# toc: false
# comments: false
# title: 3.15 Random Values
# description: Learn random values in Python using the five-part LxD lesson format.
# permalink: /python/random
# authors: Ruhaan Bansal, Deyar Raissadat, Arya Taghavi Zargar
# ---

# %% [markdown]
# A **random value** is selected from a set or range of possible values. Python is the main language for this lesson. JavaScript and College Board pseudocode are only used to compare the same idea in different forms.
#
# ## 1. LxD Cycle Process
#
# **Empathize:** Random code can be confusing because students may expect every result to appear once before a repeat, forget that `randint` includes both endpoints, or choose a range with the wrong values.
#
# **Define:**
# - **POV:** CSP students need a simple way to connect familiar random events, such as dice rolls, to the code that creates random values.
# - **Learning Goal:** Students will be able to generate, test, and explain random values in Python.
#
# **Ideate:**
# - **HMW Question:** How might we show randomness in a way that students can predict the possible outputs even though they cannot predict the exact next result?
# - **Activity:** Predict ranges, use `random.choice`, fix a wrong range, and build a small dice game.
#
# **Prototype & Test:** Use the Popcorn Hacks below to check whether students can list possible outputs, recognize valid ranges, and use a random result inside a decision.
#
# ---
#
# ## 2. Lesson Plan
#
# **Learning Objective:** By the end of this lesson, you will be able to use Python's `random` module to generate random integers, choose random list items, and use random results in a program.
#
# **Success Criteria:** You can identify every possible output of a random expression, choose the correct range, and explain why repeated results are allowed.
#
# ### Tech Talk 1: Random Integers
#
# Python's built-in `random` module gives us tools for random values.

# %%
# CODE_RUNNER: Run the random integer example

import random

die_roll = random.randint(1, 6)
print("Die roll:", die_roll)

# %% [markdown]
# `random.randint(a, b)` can return any whole number from `a` through `b`, including both endpoints.
#
# For a normal die, the possible results are `1`, `2`, `3`, `4`, `5`, and `6`.
#
# ### Tech Talk 2: Random Choices
#
# Python can choose directly from a list.

# %%
# CODE_RUNNER: Run the random choice example

import random

activities = ["study", "stretch", "walk", "get water"]
pick = random.choice(activities)

print("Random activity:", pick)

# %% [markdown]
# The result must be one item from the list.
#
# The same random-integer idea looks like this in the three forms:
#
# | Form | Random integer from 1 through 6 |
# | --- | --- |
# | Python | `random.randint(1, 6)` |
# | JavaScript | `Math.floor(Math.random() * 6) + 1` |
# | College Board pseudocode | `RANDOM(1, 6)` |
#
# ### Tech Talk 3: Use Random Values in Decisions
#
# A program can generate a random value and then use that result in an `if` statement.

# %%
# CODE_RUNNER: Run the random decision example

import random

flip = random.randint(1, 2)

if flip == 1:
    print("Heads")
else:
    print("Tails")

# %% [markdown]
# Random does **not** mean every possible result appears once before a repeat. Repeats are normal.
#
# ---
#
# ## 3. Popcorn Hacks & Practice Tasks
#
# > **SFI car/backend build:** These four hacks progressively build a small randomized QA workflow for automotive SFI specification records. Do them in order: first choose a record number, then choose a structured part record, then randomize an API action, and finally build a multi-test backend simulator.
#
# ### Popcorn Hack 1: Randomly Choose a Valid SFI Record Number
#
# A QA script has four SFI part records numbered `1` through `4`. The starter code runs, but the random range is intentionally incomplete.
#
# **Do the work:**
# 1. Change the `randint` call so every valid record number from 1 through 4 can be selected.
# 2. Write down every possible output before running.
# 3. Run the code at least five times and record the results.
# 4. Explain why repeats are allowed.

# %%
# CODE_RUNNER: Popcorn Hack 1 - Random SFI Record Number

import random

record_count = 4

# TODO: Fix the upper bound so IDs 1, 2, 3, and 4 are all possible.
selected_record_number = random.randint(1, 1)

print("Selected SFI record number:", selected_record_number)

# %% [markdown]
# ### Popcorn Hack 2: Randomly Choose a Structured SFI Car Part
#
# Now move from a number to real backend-style records. Each dictionary contains fields similar to the SFI spec database.
#
# **Do the work:**
# 1. Replace `parts[0]` with `random.choice(parts)`.
# 2. Add a **fourth automotive/racing part record** with a product name, category, and spec number.
# 3. Run the code at least five times.
# 4. Record which records appeared and explain why a record can repeat before every record has appeared.

# %%
# CODE_RUNNER: Popcorn Hack 2 - Random SFI Part Record

import random

parts = [
    {
        "product_name": "Replacement Flywheels and Clutch Assemblies",
        "category": "Auto Racing",
        "spec_number": "1.1"
    },
    {
        "product_name": "Multiple Disc Clutch Assemblies",
        "category": "Drag Racing",
        "spec_number": "1.2"
    },
    {
        "product_name": "Racing Flywheel Record",
        "category": "Auto Racing",
        "spec_number": "2.1"
    }
]

# TODO: Replace deterministic selection with random.choice(parts).
selected_part = parts[0]

print("Product:", selected_part["product_name"])
print("Category:", selected_part["category"])
print("Spec:", selected_part["spec_number"])

# %% [markdown]
# ### Popcorn Hack 3: Randomize Both the Part and the Backend Action
#
# A QA test is more useful if it varies both **what record** is tested and **what API action** is simulated.
#
# Use these backend-style actions:
# - `GET/search`
# - `POST/create`
# - `PUT/update`
#
# **Do the work:**
# 1. Replace the deterministic part selection with `random.choice(parts)`.
# 2. Replace the deterministic action selection with `random.choice(actions)`.
# 3. Run the code at least six times and record the part/action combinations.
# 4. Add one more action from the SFI backend, such as `DELETE/remove`.
# 5. Explain why the number of possible combinations is larger than the number of parts.

# %%
# CODE_RUNNER: Popcorn Hack 3 - Random SFI API Test

import random

parts = [
    {"product_name": "Replacement Flywheels", "spec_number": "1.1"},
    {"product_name": "Multiple Disc Clutch Assemblies", "spec_number": "1.2"},
    {"product_name": "Racing Flywheel Record", "spec_number": "2.1"}
]

actions = [
    "GET/search",
    "POST/create",
    "PUT/update"
]

# TODO 1: make the part selection random.
selected_part = parts[0]

# TODO 2: make the backend action random.
selected_action = actions[0]

print("Testing part:", selected_part["spec_number"], "-", selected_part["product_name"])
print("API action:", selected_action)

if selected_action == "GET/search":
    print("Simulate returning this part from a search.")
elif selected_action == "POST/create":
    print("Simulate validating this part before creating it.")
else:
    print("Simulate updating this existing part record.")

# %% [markdown]
# ### Popcorn Hack 4 / Homework: Build an SFI Backend QA Simulator
#
# This final hack combines everything from Hacks 1–3. Your simulator should run several randomized backend tests in one execution.
#
# The scaffold already contains:
# - structured SFI automotive records,
# - a list of backend actions,
# - existing spec numbers,
# - and a five-test loop.
#
# **Do the work:**
# 1. Replace both deterministic selections with `random.choice(...)`.
# 2. Add `"DELETE/remove"` to the actions list.
# 3. Complete the `DELETE/remove` branch so it prints a meaningful simulated backend result.
# 4. Keep the provided `POST/create` duplicate check: existing spec numbers should be rejected, new spec numbers can be accepted.
# 5. Add a **fourth SFI part record** with a spec number not already in `existing_spec_numbers` so a POST can sometimes succeed.
# 6. Run the simulator multiple times and capture at least five test lines on your portfolio page.
# 7. In 2–3 sentences, explain how randomness helps QA discover different backend paths and why repeated tests are still valid.

# %%
# CODE_RUNNER: Popcorn Hack 4 / Homework - SFI Backend QA Simulator

import random

parts = [
    {
        "product_name": "Replacement Flywheels",
        "category": "Auto Racing",
        "spec_number": "1.1"
    },
    {
        "product_name": "Multiple Disc Clutch Assemblies",
        "category": "Drag Racing",
        "spec_number": "1.2"
    },
    {
        "product_name": "Racing Flywheel Record",
        "category": "Auto Racing",
        "spec_number": "2.1"
    }
]

actions = [
    "GET/search",
    "POST/create",
    "PUT/update"
    # TODO: Add "DELETE/remove".
]

existing_spec_numbers = ["1.1", "2.1"]

for test_number in range(1, 6):
    # TODO 1: replace with random.choice(parts)
    selected_part = parts[0]

    # TODO 2: replace with random.choice(actions)
    selected_action = actions[0]

    spec_number = selected_part["spec_number"]

    if selected_action == "GET/search":
        result = "RETURN matching record"
    elif selected_action == "POST/create":
        duplicate_spec = spec_number in existing_spec_numbers
        result = "REJECT duplicate" if duplicate_spec else "ACCEPT new record"
    elif selected_action == "PUT/update":
        result = "VALIDATE then update record"
    else:
        # TODO 3: Replace this message with a meaningful DELETE/remove result.
        result = "TODO delete behavior"

    print(
        "Test", test_number,
        "|", selected_action,
        "| Spec", spec_number,
        "|", selected_part["product_name"],
        "|", result
    )

# %% [markdown]
# ---
#
# ## 4. Grading Plan (1 Point Total)
#
# The hacks intentionally increase in difficulty. Your portfolio page should show the **completed code, actual runner output, and short explanations**.
#
# | Activity | Points | What earns the points |
# | --- | ---: | --- |
# | Popcorn Hack 1 | 0.15 | Fix the valid random range, list possible outputs, record at least five runs, and explain repeats. |
# | Popcorn Hack 2 | 0.20 | Use `random.choice()` on structured SFI records, add a fourth part, record runs, and explain repeated selections. |
# | Popcorn Hack 3 | 0.25 | Randomize both the part and API action, add a fourth backend action, record at least six combinations, and explain the larger outcome space. |
# | Popcorn Hack 4 / Homework | 0.40 | Build the multi-test QA simulator, add DELETE behavior and a new-spec record, preserve duplicate POST validation, capture test output, and explain the QA value of randomness. |
# | **Total** | **1.0** | |
#
# ---
#
# ## 5. Lesson Revisions & Feedback Evidence
#
# - The lesson and Tech Talks keep their original general examples.
# - Hacks 1–4 now build progressively from a random record number to a structured SFI backend QA simulator.
# - The examples use automotive SFI part records, spec numbers, and backend-style GET/POST/PUT/DELETE actions.
# - Every hack has its own standalone, valid Python runner with a `# CODE_RUNNER:` label and visible output.
# - TODO scaffolds run without syntax errors, but students must modify code, test it repeatedly, record outputs, and explain the behavior.
#
# ---
#
# ## 6. Submit Assignment
#
# Put your completed work on **your own published portfolio/blog page** so your answers and test evidence are recorded.
#
# Your page must contain:
# 1. `## Popcorn Hack 1` — corrected range, possible outputs, at least five actual runs, and repeat explanation.
# 2. `## Popcorn Hack 2` — completed random part selector, your fourth record, actual outputs, and explanation.
# 3. `## Popcorn Hack 3` — randomized part/action code, your added backend action, at least six combinations, and explanation.
# 4. `## Popcorn Hack 4` — completed QA simulator, DELETE behavior, added new-spec record, captured test lines, and 2–3 sentence QA explanation.
#
# **Submission steps:**
# - Commit and push the portfolio/blog page.
# - Open the **published page** and verify the code, outputs, and explanations are visible.
# - Copy the full published URL, not the GitHub editor/repository URL.
# - Paste that URL into the built-in **Link Submission** form directly below this lesson.
# - In the description, write: `3.15 Random SFI backend hacks 1-4 complete`.
#
# The assignment form is generated by this lesson itself; no Google Form is needed.
