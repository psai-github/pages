# %% [raw]
# ---
# layout: post
# categories: [Python, Mathematical-Expressions]
# lesson_language: Python
# lesson_topic: Mathematical-Expressions
# lesson_part: interactive
# lesson_type: lesson
# codemirror: true
# microblog: true
# assignment: true
# toc: false
# title: 3.03 Math Expressions
# permalink: /csp/python/math-expressions/lesson
# Authors: Adya S, Anika S, Jailene T
# ---

# %% [markdown]
# ## **Math Expressions Lesson**

# %% [markdown]
# ### **Part 1 — The Basics: What is a Math Expression?**
#
# **Why this matters:** Every program that calculates a price, a score, a distance, or a time is built on math expressions. A math expression combines numbers and operators so the computer evaluates them into a single new value — without expressions, a program can only store numbers, it can never actually *do* anything with them.
#
# Python uses the same basic operators as a calculator:

# %% [markdown]
# | Operator | Meaning | Description | Usage Example |
# | :---: | :--- | :--- | :--- |
# | **`+`** | Addition | Adds two values together. | `10 + 5` evaluates to `15` |
# | **`-`** | Subtraction | Subtracts the second value from the first. | `10 - 5` evaluates to `5` |
# | **`*`** | Multiplication | Multiplies two values. | `10 * 5` evaluates to `50` |
# | **`/`** | Division | Divides the first value by the second. | `10 / 5` evaluates to `2.0` |
# | **`**`** | Exponentiation | Raises the first value to the power of the second. | `2 ** 3` evaluates to `8` |
# | **`//`** | Floor Division | Divides and rounds down to the nearest whole number. | `10 // 3` evaluates to `3` |
# | **`%`** | Modulus | Divides and returns only the remainder. | `10 % 3` evaluates to `1` |

# %% [markdown]
# ---
#
# ### **Setting Up Your Environment**
#
# For these two popcorn hacks, as well as the homework, you'll work in **your own portfolio repository** instead of this shared lesson.
#
# #### How to Create a New Notebook in Your Portfolio
#
# <div class="ocs__grid ocs__grid--standard cols-2">
#   <div class="ocs__grid-cell"><strong>1.</strong> Open your portfolio repository in VS Code (or your editor of choice).</div>
#
#   <div class="ocs__grid-cell"><strong>2.</strong> Inside your <code>_notebooks</code> folder, create a new file: <code>YYYY-MM-DD-math-expressions-hw.ipynb</code>.</div>
#
#   <div class="ocs__grid-cell"><strong>3.</strong> Add a raw/markdown cell at the top with the frontmatter provided. OR Copy paste this file into your portfolio and change frontmatter accordingly. ➡️</div>
#
#   <div class="ocs__grid-cell">
#     <pre>---
# layout: post
# categories: [Python, Mathematical-Expressions]
# lesson_language: Python
# lesson_topic: Mathematical-Expressions
# lesson_part: interactive
# lesson_type: lesson
# title: 3.3 Math Expressions HW
# permalink: /csp/python/math-expressions/hw
# Authors: YourName
# ---</pre>
#   </div>
#
#   <div class="ocs__grid-cell"><strong>4.</strong> Add a code cell for each task below and write your Python math expressions there. Make sure to title each section using a Markdown block (i.e. Popcorn Hack 1, Popcorn Hack 2, HW).</div>
#
#   <div class="ocs__grid-cell"><strong>5.</strong> Run each cell (▶ Run or Shift+Enter) to check your output before moving on.</div>
#
#   <div class="ocs__grid-cell"><strong>6.</strong> Commit and push your notebook, then confirm it builds on your portfolio site.</div>
# </div>

# %% [markdown]
# ---
#
# ### **Popcorn Hack 1: Try the Basics**
#
# Fill in the TODOs below using the operators you just learned, then press Run to check your results.

# %%
# CODE_RUNNER: Popcorn Hack - Basic Arithmetic Operators
value_a = 100
value_b = 10
value_c = 25

# TODO: calculate total of A, B, and C using the variables above
addition = 0  # Replace with your expression (e.g., value_a + value_b + value_c)

# TODO: calculate the difference between items A and B using the variables above
subtraction = 0  # Replace with your expression

# TODO: calculate the product of items B and C using the variables above
multiplication = 0  # Replace with your expression

# TODO: divide value A by value B and output the division using the variables above
division = 0  # Replace with your expression

print("Total:", addition)
print("Difference:", subtraction)
print("Product:", multiplication)
print("Division:", division)
# Out:
# Total: 0
# Difference: 0
# Product: 0
# Division: 0

# %% [markdown]
# ---
#
# ### **Going Deeper: Mathematical Expressions**
#
# Most expressions you write use **infix notation** — the operator sits between the numbers, like `5 + 3`. Computers don't have to evaluate math that way.
#
# RPN removes the need for parentheses and order-of-operations rules — every expression can be evaluated left to right using an algorithm.  Create a data structure stack (like plates), first-in, first-out.
#
# Step | Input Queue | Operation | Stack
# -- | -- | -- | --
# 1 | 5 3 - 2 * | Push 5 | [5]
# 2 | 3 - 2 * | Push 3 | [5, 3]
# 3 | - 2 * | Pop 3, pop 5 → 5 - 3 → push 2 | [2]
# 4 | 2 * | Push 2 | [2, 2]
# 5 | * | Pop 2, pop 2 → 2 × 2 → push 4 | [4]
# 6 | (empty) | Result | [4]
#
# This is important as we often think the human representation of a problem is simple, but computer algorithms are required behind the scenes for everything we do on computers.  RPN is still used today in some scientific and financial calculators because it’s fast and never ambiguous.

# %% [markdown]
# ---
#
# ### **Popcorn Hack 2: Project Based Math-Expression Hack**

# %% [markdown]
# The significance of the Popcorn hack is that it teaches you how to write code that actually scales. Instead of hardcoding numbers into the print statement messages, you learn to use variables so features like the Poway Recovery Center booking system can automatically update and calculate data in real time.
#
# In your new notebook, add a code cell and use math expressions to calculate the weekly and monthly cost of attending sessions at a recovery center.
#
# **Given:**
# - `cost_per_session = 35`
# - `sessions_per_week = 3`
# - `weeks_per_month = 4`
#
# **Calculate and print:**
# 1. `weekly_cost` — cost per session × sessions per week
# 2. `monthly_cost` — weekly cost × weeks per month
#
# **Bonus: Write your code in pseudocode AND Python.**
#
# Run your cell to confirm the output before moving on to the homework below.

# %%
SET total_monthly_capacity TO 100
SET spots_requested_per_group TO 4
SET sessions_booked TO 3

// 1. Multiplication: total spots taken by the booking group
// PUT CODE HERE

// 2. Subtraction: remaining capacity for the center
// PUT CODE HERE

// 3. Division: distribute remaining spots evenly across 2 rooms
// PUT CODE HERE

DISPLAY "Total Spots Taken:", // PUT CODE HERE
DISPLAY "Remaining Capacity:", // PUT CODE HERE
DISPLAY "Users per Room:", // PUT CODE HERE

# %%
# Grouping operations for the Poway Recovery Center booking system
total_monthly_capacity = 100
spots_requested_per_group = 4
sessions_booked = 3

# 1. Multiplication: Calculate total spots taken by the booking group
# PUT YOUR CODE HERE

# 2. Subtraction: Calculate remaining capacity for the center
# PUT YOUR CODE HERE

# 3. Division: Distribute remaining spots evenly across 2 active rooms
# PUT YOUR CODE HERE

# Print the final outputs - EDIT THE CODE BELOW
print("Total Spots Taken:", )
print("Remaining Capacity:", )
print("Users per Room:", )
# Out:
# Total Spots Taken:
# Remaining Capacity:
# Users per Room:

# %% [markdown]
# ---
#
# ### 🎁 Bonus: Building a Calculator with Math Expressions
#
# Every calculator app is really just a UI wrapped around the same math expressions you practiced in this lesson — `+`, `-`, `*`, and `/` acting on two operands. The calculator below is styled with this site's own Sass calculator component (`variant-calculator.scss`), and it has **fully working buttons** — try it out! Can you match the Poway Recovery Center calculations?
#
# <div class="calculator-demo">
#   <div class="calculator-container" id="lesson-calculator">
#     <!-- Display -->
#     <div class="calculator-output" id="lesson-calc-output">0</div>
#
#     <!-- Row 1 -->
#     <div class="calculator-clear" data-action="clear">AC</div>
#     <div class="calculator-special" data-action="percent">%</div>
#     <div class="calculator-special" data-action="sqrt">&radic;</div>
#     <div class="calculator-operation" data-op="/">&divide;</div>
#
#     <!-- Row 2 -->
#     <div class="calculator-number" data-num="7">7</div>
#     <div class="calculator-number" data-num="8">8</div>
#     <div class="calculator-number" data-num="9">9</div>
#     <div class="calculator-operation" data-op="*">&times;</div>
#
#     <!-- Row 3 -->
#     <div class="calculator-number" data-num="4">4</div>
#     <div class="calculator-number" data-num="5">5</div>
#     <div class="calculator-number" data-num="6">6</div>
#     <div class="calculator-operation" data-op="-">-</div>
#
#     <!-- Row 4 -->
#     <div class="calculator-number" data-num="1">1</div>
#     <div class="calculator-number" data-num="2">2</div>
#     <div class="calculator-number" data-num="3">3</div>
#     <div class="calculator-operation" data-op="+">+</div>
#
#     <!-- Row 5 -->
#     <div class="calculator-number zero" data-num="0">0</div>
#     <div class="calculator-number" data-num=".">.</div>
#     <div class="calculator-equals" data-action="equals">=</div>
#   </div>
# </div>
#
# <script>
# (function () {
#   const root = document.getElementById("lesson-calculator");
#   const output = document.getElementById("lesson-calc-output");
#
#   let displayValue = "0";
#   let firstOperand = null;
#   let operator = null;
#   let waitingForSecondOperand = false;
#
#   function updateDisplay() {
#     output.textContent = displayValue;
#   }
#
#   function calculate(first, second, op) {
#     switch (op) {
#       case "+": return first + second;
#       case "-": return first - second;
#       case "*": return first * second;
#       case "/": return second === 0 ? "Error" : first / second;
#       default: return second;
#     }
#   }
#
#   function inputDigit(digit) {
#     if (waitingForSecondOperand) {
#       displayValue = digit;
#       waitingForSecondOperand = false;
#     } else {
#       displayValue = displayValue === "0" ? digit : displayValue + digit;
#     }
#   }
#
#   function inputDecimal() {
#     if (waitingForSecondOperand) {
#       displayValue = "0.";
#       waitingForSecondOperand = false;
#       return;
#     }
#     if (!displayValue.includes(".")) {
#       displayValue += ".";
#     }
#   }
#
#   function handleOperator(nextOperator) {
#     const inputValue = parseFloat(displayValue);
#
#     if (operator && waitingForSecondOperand) {
#       operator = nextOperator;
#       return;
#     }
#
#     if (firstOperand === null) {
#       firstOperand = inputValue;
#     } else if (operator) {
#       const result = calculate(firstOperand, inputValue, operator);
#       displayValue = String(result);
#       firstOperand = result;
#     }
#
#     waitingForSecondOperand = true;
#     operator = nextOperator;
#   }
#
#   function handleEquals() {
#     if (operator === null || waitingForSecondOperand) return;
#     const inputValue = parseFloat(displayValue);
#     displayValue = String(calculate(firstOperand, inputValue, operator));
#     firstOperand = null;
#     operator = null;
#     waitingForSecondOperand = false;
#   }
#
#   function handleClear() {
#     displayValue = "0";
#     firstOperand = null;
#     operator = null;
#     waitingForSecondOperand = false;
#   }
#
#   function handlePercent() {
#     const value = parseFloat(displayValue);
#     if (!isNaN(value)) displayValue = String(value / 100);
#   }
#
#   function handleSqrt() {
#     const value = parseFloat(displayValue);
#     displayValue = !isNaN(value) && value >= 0 ? String(Math.sqrt(value)) : "Error";
#   }
#
#   root.querySelectorAll(".calculator-number").forEach((button) => {
#     button.addEventListener("click", () => {
#       const value = button.dataset.num;
#       if (value === ".") {
#         inputDecimal();
#       } else {
#         inputDigit(value);
#       }
#       updateDisplay();
#     });
#   });
#
#   root.querySelectorAll(".calculator-operation").forEach((button) => {
#     button.addEventListener("click", () => {
#       handleOperator(button.dataset.op);
#       updateDisplay();
#     });
#   });
#
#   root.querySelectorAll(".calculator-equals").forEach((button) => {
#     button.addEventListener("click", () => {
#       handleEquals();
#       updateDisplay();
#     });
#   });
#
#   root.querySelectorAll(".calculator-clear").forEach((button) => {
#     button.addEventListener("click", () => {
#       handleClear();
#       updateDisplay();
#     });
#   });
#
#   root.querySelectorAll(".calculator-special").forEach((button) => {
#     button.addEventListener("click", () => {
#       if (button.dataset.action === "percent") handlePercent();
#       if (button.dataset.action === "sqrt") handleSqrt();
#       updateDisplay();
#     });
#   });
# })();
# </script>

# %% [markdown]
# ---
#
# ## 📝 Homework (10 Minutes): Recovery Center Cost Report
#
# In the **same portfolio notebook**, add a new code cell below your interactive task and build a full cost report.
#
# **Given:**
# - `cost_per_session = 35`
# - `sessions_per_week = 3`
# - `weeks_per_month = 4`
# - `enrollment_fee = 75` (one-time cost)
#
# **Calculate and print each of the following:**
# 1. `weekly_cost` — cost per session × sessions per week
# 2. `monthly_cost` — weekly cost × weeks per month
# 3. `total_cost_with_fee` — monthly cost plus the one-time enrollment fee
# 4. `average_daily_cost` — monthly cost divided by 30
#
# Commit and push your notebook when you're done — you'll link it in the submission form below.

# %%
# Recovery Center Cost Report
cost_per_session = 35
sessions_per_week = 3
weeks_per_month = 4
enrollment_fee = 75

# 1. Calculate weekly cost


# 2. Calculate monthly cost


# 3. Calculate total cost with fee


# 4. Calculate average daily cost


# Print all results with labels
print("Weekly Cost:", )
print("Monthly Cost:", )
print("Total Cost with Fee:", )
print("Average Daily Cost:", )
# Out:
# Weekly Cost:
# Monthly Cost:
# Total Cost with Fee:
# Average Daily Cost:

# %% [markdown]
# ### 📊 Grading Plan
#
# <div class="ocs__grid ocs__grid--standard cols-2">
#   <div class="ocs__grid-cell ocs__grid-cell--header">Homework Grading Plan — 1.0 Total</div>
#   <div class="ocs__grid-cell"><strong>0.2</strong> — Correct <code>weekly_cost</code> expression</div>
#   <div class="ocs__grid-cell"><strong>0.2</strong> — Correct <code>monthly_cost</code> expression</div>
#   <div class="ocs__grid-cell"><strong>0.2</strong> — Correct <code>total_cost_with_fee</code> expression</div>
#   <div class="ocs__grid-cell"><strong>0.2</strong> — Correct <code>average_daily_cost</code> expression</div>
#   <div class="ocs__grid-cell"><strong>0.2</strong> — Code runs without errors and every result is printed with a label</div>
# </div>
#
# ### 📤 Submit Your Homework
#
# Once your notebook is committed and pushed, submit your portfolio link using the form below.
#
# <a class="ocs__btn accent fill" href="https://forms.gle/mi5cLycuyjdaZo5t7" target="_blank" rel="noopener">Submit Homework →</a>

# %% [markdown]
# ### 1. LxD Cycle Process
#
# **Empathize:** We noticed that students learning basic Python math expressions often get overwhelmed and confused when we wrap basic arithmetic in long, multi-step storylines, creating unnecessary cognitive load before they even grasp the core syntax.
#
# **Define:**
#
# - **POV:** CSP students need a streamlined way to practice Python operators and variables without confusing storylines because wrapping basic math in unrelated themes creates unnecessary cognitive load.
# - **Learning Goal:** Students will understand how to assign values to variables and use Python arithmetic operators (`+`, `-`, `*`, `/`) with clean, straightforward examples.
#
# **Ideate:**
#
# - **HMW Question:** How might we teach Python math expressions cleanly without distracting stories or overly complex themes?
# - **Activity:** A direct, theme-free code walkthrough using `value_a` and `value_b`, paired with a straightforward currency conversion homework task.
#
# **Prototype & Test:** We originally drafted lessons with multi-step real-world themes, but feedback showed students preferred a clean, distraction-free structure. We streamlined the lesson to focus strictly on foundational operators.

# %% [markdown]
# ### 2. Lesson Plan
#
# **Learning Objective:** By the end of this lesson, you will be able to write dynamic math expressions using Python operators so your program automatically calculates outputs based on variable inputs for the Poway Recovery Center platform.
#
# **Success Criteria:** You can take raw numbers for session capacity and group bookings, assign them to variables, apply the correct arithmetic operators, and print the evaluated result.
#
# **Tech Talk (3 minutes)**
# When building the Poway Recovery Center website, you need code that can handle real-time user bookings. This means you don’t need to do the math yourself. Instead of figuring out remaining slots and typing them in, you tell the computer *how* to calculate it using variables and operators.
#
# **The Rule:** Use variables and operators. Let Python handle the evaluation.
# *   ✅ **Do this:** `remaining_capacity = total_capacity - (group_size * sessions)` followed by `print(remaining_capacity)`
# *   ❌ **Don’t do this:** `print("There are 88 spots left")`
#
# Why do we do this? It ensures our platform updates dynamically when users book sessions, makes our code reusable, and powers real-world app features.
