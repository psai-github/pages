# %% [raw]
# ---
# layout: post
# categories: [Python, Boolean-Expressions]
# lesson_language: Python
# lesson_topic: Boolean-Expressions
# lesson_part: interactive
# lesson_type: lesson
# codemirror: true
# microblog: true
# toc: false
# comments: false
# title: 3.05 Boolean Expressions
# description: Learn Boolean expressions in Python using the five-part LxD lesson format.
# permalink: /python/boolean
# ---

# %% [markdown]
# A **Boolean expression** is a question that evaluates to only `True` or `False`. Python is the main language for this lesson. JavaScript and College Board pseudocode are only used to compare the same idea in different forms.
#
# ## 1. LxD Cycle Process
#
# **Empathize:** Boolean expressions can look simple, but it is easy to mix up `and` and `or`, forget a boundary such as `>=`, or write a condition that does not match the rule in normal English.
#
# **Define:**
# - **POV:** CSP students need a clear way to turn real-world rules into Boolean expressions so their programs make the correct decisions.
# - **Learning Goal:** Students will be able to evaluate, write, test, and explain Boolean expressions in Python.
#
# **Ideate:**
# - **HMW Question:** How might we make Boolean logic easier to understand before students have to write a full program?
# - **Activity:** Predict Boolean results, fix an incorrect condition, and then build one complete decision checker.
#
# **Prototype & Test:** Use the Popcorn Hacks below to check whether students can predict results before running code, choose the correct Boolean operator, and explain why their expression matches the rule.
#
# ---
#
# ## 2. Lesson Plan
#
# **Learning Objective:** By the end of this lesson, you will be able to use comparisons, `and`, `or`, and `not` to create Boolean expressions and use them in Python decisions.
#
# **Success Criteria:** You can predict whether an expression is `True` or `False`, write a condition from a rule in normal English, and test the condition with more than one set of values.
#
# ### Tech Talk 1: Comparisons Create Booleans
#
# Python comparison operators return `True` or `False`.
#
# | Python | Meaning | Example |
# | --- | --- | --- |
# | `==` | equal to | `score == 90` |
# | `!=` | not equal to | `score != 0` |
# | `>` | greater than | `score > 70` |
# | `<` | less than | `age < 18` |
# | `>=` | greater than or equal to | `score >= 70` |
# | `<=` | less than or equal to | `age <= 18` |

# %%
# CODE_RUNNER: Run the Boolean expression example

score = 82

print(score >= 70)
print(score == 100)
print(score != 0)

# %% [markdown]
# Remember:
# - `score = 90` assigns a value.
# - `score == 90` compares two values.
#
# ### Tech Talk 2: `and`, `or`, and `not`
#
# Sometimes one comparison is not enough.
#
# | Idea | Python | JavaScript | College Board pseudocode |
# | --- | --- | --- | --- |
# | both must be true | `and` | `&&` | `AND` |
# | at least one is true | `or` | `||` | `OR` |
# | reverse true/false | `not` | `!` | `NOT` |

# %%
# CODE_RUNNER: Run the Boolean operators example

has_id = True
has_ticket = False

print(has_id and has_ticket)
print(has_id or has_ticket)
print(not has_ticket)

# %% [markdown]
# A longer expression can be read one part at a time:

# %%
# CODE_RUNNER: Run the compound Boolean example

age = 16
is_teenager = age >= 13 and age <= 19
print(is_teenager)

# %% [markdown]
# ### Tech Talk 3: Booleans Control `if` Statements
#
# An `if` statement runs when its condition is true.

# %%
# CODE_RUNNER: Run the if statement example

temperature = 72

if temperature >= 70:
    print("It is warm outside.")
else:
    print("It is not warm outside.")

# %% [markdown]
# The same basic decision in College Board pseudocode is:
#
# ```text
# IF(temperature ≥ 70)
# {
#     DISPLAY("It is warm outside.")
# }
# ELSE
# {
#     DISPLAY("It is not warm outside.")
# }
# ```
#
# ---
#
# ## 3. Popcorn Hacks & Practice Tasks
#
# > **SFI car/backend theme:** The exercises below use automotive SFI specification records from the project backend. Think about car and racing parts, database fields such as `product_name`, `category`, `spec_number`, and `effective_date`, plus backend search and CRUD logic. One real dataset example is **Replacement Flywheels and Clutch Assemblies (SFI Spec 1.1)**.
#
# ### Popcorn Hack 1: Predict Before You Run
#
# The backend is checking an SFI car-part record before returning it. Predict each Boolean result first, then run the code and compare.

# %%
# CODE_RUNNER: Run Popcorn Hack 1

part_in_database = True
spec_number_matches = True
category_is_auto_racing = True
record_archived = False

print(part_in_database)
print(spec_number_matches and category_is_auto_racing)
print(not record_archived)
print(part_in_database and spec_number_matches and not record_archived)

# %% [markdown]
# For each line, write `True` or `False` and one short reason.
#
# ### Popcorn Hack 2: Fix the Part Update Logic
#
# Imagine the SFI backend receives a `PUT` request to update a racing-part specification record. The update should happen only when the **part record exists AND the new spec value is valid**.

# %%
# CODE_RUNNER: Run Popcorn Hack 2

part_exists = True
new_spec_is_valid = False

# Fix the condition so BOTH backend requirements are needed.
can_update_part = part_exists or new_spec_is_valid

if can_update_part:
    print("Update the SFI part record")
else:
    print("Reject the update")

# %% [markdown]
# Do these four things:
# 1. Predict what the current code prints.
# 2. Fix the Boolean expression.
# 3. Test at least three combinations of `part_exists` and `new_spec_is_valid`.
# 4. Explain why this backend rule needs `and` or `or`.
#
# ### Popcorn Hack 3: Translate the Part Search Logic
#
# The SFI backend search can find a car-part specification when the query matches either the **product name** or the **spec number**.
#
# Start with this Python expression:
#
# `product_name_match or spec_number_match`
#
# The runner below gives both variables values so it executes cleanly.

# %%
# CODE_RUNNER: Run Popcorn Hack 3

product_name_match = False
spec_number_match = True

return_part_record = product_name_match or spec_number_match
print(return_part_record)

# %% [markdown]
# Write the same `product_name_match or spec_number_match` Boolean expression in JavaScript and College Board pseudocode. Then explain why **or** is the correct operator for a backend search.
#
# ### Popcorn Hack 4 / Homework: SFI Car-Part Record Validator
#
# Build one Boolean expression for a backend create-request scenario.
#
# The backend should accept a new SFI car-part specification record only when:
# - it has a product name,
# - its category is **Auto Racing or Drag Racing**,
# - it has a spec number,
# - and it is **not** a duplicate record.

# %%
# CODE_RUNNER: Run Popcorn Hack 4 / Homework

has_product_name = True
category_is_auto_racing = True
category_is_drag_racing = False
has_spec_number = True
duplicate_record = False

# Replace False with one Boolean expression using all five values.
can_create_part_record = False

if can_create_part_record:
    print("Create SFI car-part record")
else:
    print("Reject car-part record")

# %% [markdown]
# Test at least four cases, including one duplicate record and one record with no spec number. Then explain your Boolean expression in 2–3 sentences.
#
# ---
#
# ## 4. Grading Plan (1 Point Total)
#
# | Activity | Points | What earns the points |
# | --- | ---: | --- |
# | Popcorn Hack 1 | 0.2 | Correctly predict each Boolean result and include a short explanation. |
# | Popcorn Hack 2 | 0.2 | Fix the backend part-update Boolean logic and test at least three combinations. |
# | Popcorn Hack 3 | 0.2 | Correctly translate the product-name-or-spec-number search expression into JavaScript and College Board pseudocode. |
# | Popcorn Hack 4 / Homework | 0.4 | Build the SFI car-part record validation expression using all required conditions, test at least four cases, and explain the final expression in 2–3 sentences. |
# | **Total** | **1.0** | |
#
# ---
#
# ## 5. Lesson Revisions & Feedback Evidence
#
# - The lesson and Tech Talks keep their original general examples.
# - The Popcorn Hacks and homework now focus on SFI automotive parts and backend database/API logic.
# - The examples use backend-style fields and operations such as part records, spec numbers, search, create, and update.
# - Runner cells define their variables and print visible output so they execute cleanly.
# - Python stays the main coding language, while JavaScript and College Board pseudocode are short comparison aids.
# - Feedback from a practice run can be added here with the specific change that was made because of it.
